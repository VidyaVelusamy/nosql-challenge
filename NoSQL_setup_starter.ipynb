# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %% [markdown]
# mongoimport --type json -d uk_food -c establishments --jsonArray establishments.json

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'epa', 'fruits_db', 'gardenDB', 'local', 'met', 'petsitly_marketing', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
db['establishments'].find_one()
# Out:
# {'_id': ObjectId('66a2926494f0d5feaf725838'),
#  'FHRSID': 254719,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT15 6DY',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2022-03-24T00:00:00',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.387974', 'latitude': '51.152225'},
#  'RightToReply': '',
#  'Distance': 4587.347174863443,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/254719'}]}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
restaurant={
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(restaurant)
# Out:
# InsertOneResult(ObjectId('66a296bc52a0c284841b1ebe'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
query={"BusinessName":"Penang Flavours"}
results = establishments.find(query)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a296bc52a0c284841b1ebe'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query={ 'BusinessType': 'Restaurant/Cafe/Canteen'}
fields = {'BusinessTypeID': 1, 'BusinessType': 1}
results = establishments.find(query,fields)
for result in results:
    pprint(result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725838')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725839')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72583a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72583b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72583c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72583d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725842')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725844')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725849')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72584a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72584d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725850')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725855')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725858')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72585c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725863')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725868')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72586a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72586c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725870')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725874')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725875')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725876')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725878')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72587a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72587f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725880')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725882')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725884')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725887')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725889')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72588d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72588e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72588f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725892')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725896')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725898')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72589b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258a3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258aa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258ba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258db')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258e3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258e5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258fd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7258fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725900')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725904')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72590b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72590e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725914')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725922')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725924')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725926')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725927')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725928')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725933')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725936')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725939')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72593a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725949')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72594a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72594c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725954')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725955')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725957')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725959')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725961')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725963')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725969')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72596f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725970')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725972')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725974')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725979')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72597d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72597e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725981')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725982')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725985')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725986')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725987')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725988')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72598c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725992')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725993')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725994')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72599b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf72599e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259a3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259b3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259bb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259d8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259da')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259f0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259fa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf7259fd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a02')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a05')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a09')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a0c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a10')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a12')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a1d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a28')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a32')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a4d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a57')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a58')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a5b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a62')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a65')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a73')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a84')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725a9b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725aa0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725aac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ab0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ab1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ac2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ac3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725acb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ad1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ad3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ad4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ad6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725adb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ae5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ae6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725aea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725aeb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725af1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725afb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725afc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725afd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b01')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b0f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b15')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b1b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b25')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b27')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b2a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b2e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b32')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b33')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b3e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b48')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b4b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b4e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b50')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b53')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b5d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b64')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b6b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b6f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b74')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b77')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b78')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b79')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b7d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b7e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b7f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b81')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b83')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b85')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b8b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b8e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b90')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b94')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b96')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b97')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b99')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725b9e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ba2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ba9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725baa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bb2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bb3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bb6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bbb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bbc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bbd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bbf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bc0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bc4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bc6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bc9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bd1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bd3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bd5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bd6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bdc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bdd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725be3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725be5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725be7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bf1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bf8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bf9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bfc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725bfe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c04')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c05')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c07')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c08')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c0a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c0c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c0e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c12')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c13')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c14')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c21')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c22')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c24')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c28')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c2a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c2d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c30')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c31')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c32')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c36')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c37')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c39')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c3c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c40')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c41')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c42')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c48')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c4e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c58')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c6f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c71')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c79')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c7b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c7e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c80')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c84')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725c9a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ca0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ca1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ca2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ca5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725caf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cb3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cb4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cb5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cb6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cb7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cb9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cbb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cbc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cbd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cbe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cbf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cc0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cc5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cd0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cd5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cd6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cd7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cd8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cda')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cdc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cdd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cde')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ce0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ce4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ce5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ce9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ced')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cf4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cf5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cf6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cf7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cfc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cfd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725cfe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d09')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d0a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d0b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d0c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d0f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d10')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d12')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d19')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d1f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d21')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d26')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d27')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d2c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d2e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d30')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d32')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d3a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d41')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d47')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d4c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d4f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d51')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d57')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d5d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d60')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d61')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d62')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d67')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d68')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d6c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d70')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d72')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d79')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d7a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d7b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d7e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d86')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d89')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d8b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d8e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d92')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d93')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d94')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d95')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d97')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d98')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d9a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d9b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d9e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725d9f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725da0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725da1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725da3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725da6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725da7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725da8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725da9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725dab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725dac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725dad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725db0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725db1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725db3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725db4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725db5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725db8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725dbf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725dc1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725dc2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725dc3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725dc4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725dcc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725dcd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725dd0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725dd1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725dd3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ddc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725de0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725dea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725deb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725ded')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725df4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725dfa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e04')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e0b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e0d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e0f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e13')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e17')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e1e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e25')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e27')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e2a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e2b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e2c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e30')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e32')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e39')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e3a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e45')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e46')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e4b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926494f0d5feaf725e4c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f187')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f188')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f189')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f18c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f190')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f195')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f196')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f197')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f199')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f19b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f19d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1a6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1ad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1b3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1d8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f1f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f200')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f201')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f207')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f209')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f22a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f233')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f236')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f23c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f23d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f23f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f241')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f245')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f247')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f24a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f251')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f252')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f256')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f25b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f261')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f26a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f26c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f273')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f277')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f284')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f288')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f28a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f28b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f28c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f28e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f290')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f295')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f299')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2a8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2b8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2c0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2eb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2fa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2fc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f2ff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f301')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f302')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f304')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f306')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f307')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f308')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f309')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f30e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f313')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f315')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f319')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f31b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f31c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f31e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f322')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f324')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f332')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f334')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f339')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f33b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f33d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f33e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f341')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f345')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f350')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f35e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f360')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f365')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f376')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f37c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f37f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f382')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f385')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f387')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f395')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('66a2926694f0d5feaf72f398')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('66a296bc52a0c284841b1ebe')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one({'BusinessName': 'Penang Flavours'},  {'$set':{ "BusinessTypeID" : 1}} )
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
query={"BusinessName":"Penang Flavours"}
results = establishments.find(query)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a296bc52a0c284841b1ebe'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query={"LocalAuthorityName":"Dover"}
results = establishments.count_documents(query)
results
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query={"LocalAuthorityName":"Dover"}
establishments.delete_many(query)
# Out:
# DeleteResult({'n': 994, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
query={"LocalAuthorityName":"Dover"}
results = establishments.count_documents(query)
results
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('66a2926494f0d5feaf725b1b'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [ {'$set':{ "geocode.longitude" : {'$toDouble': "$geocode.longitude"},"geocode.latitude" : {'$toDouble': "$geocode.latitude"}}} ])
# Out:
# UpdateResult({'n': 38786, 'nModified': 38786, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [ {'$set':{ "RatingValue" : {'$toInt': "$RatingValue"}}} ])
# Out:
# UpdateResult({'n': 38786, 'nModified': 34695, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers

fields = {'RatingValue': 1}
results = establishments.find(fields)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': '13 Guildhall Street',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Aya Supermarket',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4592.2028393215305,
#  'FHRSID': 1090853,
#  'LocalAuthorityBusinessID': 'PI/000067845',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT20 1EA',
#  'RatingDate': '2020-10-08T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf725bcc'),
#  'geocode': {'latitude': 51.080217, 'longitude': 1.1799178},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1090853',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 0, 'Structural': 15}}
# {'AddressLine1': '37-39 Canterbury Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Premier Alexander Wine',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4592.264014798041,
#  'FHRSID': 289520,
#  'LocalAuthorityBusinessID': 'PI/000035606',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 5NH',
#  'RatingDate': '2021-05-13T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf725bfd'),
#  'geocode': {'latitude': 51.087185, 'longitude': 1.185418},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289520',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 10}}
# {'AddressLine1': '9 Cheriton Place',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Prince Of India',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4592.295632854469,
#  'FHRSID': 289489,
#  'LocalAuthorityBusinessID': 'PI/000030023',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT20 2AY',
#  'RatingDate': '2021-11-24T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf725c23'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289489',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 15}}
# {'AddressLine1': '106B Cheriton Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Bridge Coffee House',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4592.590347396192,
#  'FHRSID': 683922,
#  'LocalAuthorityBusinessID': 'PI/000070438',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT20 2QN',
#  'RatingDate': '2021-09-21T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf725c84'),
#  'geocode': {'latitude': 51.082374, 'longitude': 1.171506},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/683922',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 10}}
# {'AddressLine1': '7 York Street',
#  'AddressLine2': 'Ramsgate',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Helping Hands',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4593.041558597632,
#  'FHRSID': 555381,
#  'LocalAuthorityBusinessID': 'PI/000041027',
#  'LocalAuthorityCode': '190',
#  'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#  'LocalAuthorityName': 'Thanet',
#  'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT11 9DS',
#  'RatingDate': '2015-05-22T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf725cea'),
#  'geocode': {'latitude': 51.332812, 'longitude': 1.419273},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/555381',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 5, 'Structural': 15}}
# {'AddressLine1': '55 King Street',
#  'AddressLine2': 'Ramsgate',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Queens Marvellous Creations & TGB',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4593.046511291047,
#  'FHRSID': 1400998,
#  'LocalAuthorityBusinessID': 'PI/000109804',
#  'LocalAuthorityCode': '190',
#  'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#  'LocalAuthorityName': 'Thanet',
#  'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT11 8NX',
#  'RatingDate': '2021-11-18T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf725cfc'),
#  'geocode': {'latitude': 51.3348208, 'longitude': 1.4212417},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1400998',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 10, 'Structural': 15}}
# {'AddressLine1': 'Stagecoach',
#  'AddressLine2': 'East Kent Garage',
#  'AddressLine3': 'Margate Road',
#  'AddressLine4': 'Ramsgate',
#  'BusinessName': "SAM's",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4594.771288019681,
#  'FHRSID': 658624,
#  'LocalAuthorityBusinessID': 'PI/000102426',
#  'LocalAuthorityCode': '190',
#  'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#  'LocalAuthorityName': 'Thanet',
#  'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT12 6SL',
#  'RatingDate': '2022-03-08T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf726012'),
#  'geocode': {'latitude': 51.357061, 'longitude': 1.396786},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/658624',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 10}}
# {'AddressLine1': '20 High Street',
#  'AddressLine2': 'Hythe',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Golden Bowl',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4595.449255961298,
#  'FHRSID': 289370,
#  'LocalAuthorityBusinessID': 'PI/000006771',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT21 5AT',
#  'RatingDate': '2021-07-27T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf7260cf'),
#  'geocode': {'latitude': 51.07125, 'longitude': 1.08167},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289370',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 20}}
# {'AddressLine1': 'The Street',
#  'AddressLine2': 'St Nicholas At Wade',
#  'AddressLine3': 'Birchington',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Bell Inn',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4599.791836800793,
#  'FHRSID': 370768,
#  'LocalAuthorityBusinessID': 'PI/000020991',
#  'LocalAuthorityCode': '190',
#  'LocalAuthorityEmailAddress': 'environmental.health@thanet.gov.uk',
#  'LocalAuthorityName': 'Thanet',
#  'LocalAuthorityWebSite': 'http://www.thanet.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT7 0NT',
#  'RatingDate': '2022-08-10T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf7264ab'),
#  'geocode': {'latitude': 51.353269, 'longitude': 1.253857},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/370768',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 10, 'Structural': 15}}
# {'AddressLine1': '34 Lydd Road',
#  'AddressLine2': 'Camber',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': "B J's On The Beach",
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4600.852671347163,
#  'FHRSID': 769231,
#  'LocalAuthorityBusinessID': 'PI/000159000',
#  'LocalAuthorityCode': '106',
#  'LocalAuthorityEmailAddress': 'envhealth@rother.gov.uk',
#  'LocalAuthorityName': 'Rother',
#  'LocalAuthorityWebSite': 'http://www.rother.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN31 7RJ',
#  'RatingDate': '2022-05-12T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf7264fa'),
#  'geocode': {'latitude': 50.935607, 'longitude': 0.795905},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/769231',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 10, 'Structural': 10}}
# {'AddressLine1': 'Bridge Road',
#  'AddressLine2': 'Brabourne',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Blue Anchor Public House',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4601.50964798943,
#  'FHRSID': 817962,
#  'LocalAuthorityBusinessID': 'PI/000088555',
#  'LocalAuthorityCode': '179',
#  'LocalAuthorityEmailAddress': 'envhealth@ashford.gov.uk',
#  'LocalAuthorityName': 'Ashford',
#  'LocalAuthorityWebSite': 'http://www.ashford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN25 6QQ',
#  'RatingDate': '2022-07-20T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf726528'),
#  'geocode': {'latitude': 51.124614, 'longitude': 0.970262},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/817962',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 10, 'Structural': 15}}
# {'AddressLine1': 'Pett Road',
#  'AddressLine2': 'Pett',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'Royal Oak',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4604.017634949456,
#  'FHRSID': 779155,
#  'LocalAuthorityBusinessID': 'PI/000137686',
#  'LocalAuthorityCode': '106',
#  'LocalAuthorityEmailAddress': 'envhealth@rother.gov.uk',
#  'LocalAuthorityName': 'Rother',
#  'LocalAuthorityWebSite': 'http://www.rother.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN35 4HG',
#  'RatingDate': '2022-07-27T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf726810'),
#  'geocode': {'latitude': 50.894422, 'longitude': 0.668313},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/779155',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 10, 'Structural': 10}}
# {'AddressLine1': '133 Church Road',
#  'AddressLine2': 'Willesborough',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Willesborough Tandoori',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4604.594395993568,
#  'FHRSID': 1297865,
#  'LocalAuthorityBusinessID': 'PI/000099178',
#  'LocalAuthorityCode': '179',
#  'LocalAuthorityEmailAddress': 'envhealth@ashford.gov.uk',
#  'LocalAuthorityName': 'Ashford',
#  'LocalAuthorityWebSite': 'http://www.ashford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN24 0JQ',
#  'RatingDate': '2022-08-16T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf726891'),
#  'geocode': {'latitude': 51.140795, 'longitude': 0.902269},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1297865',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 10}}
# {'AddressLine1': '82 Queens Road',
#  'AddressLine2': 'Hastings',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'Namo Kebab',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4605.842840245769,
#  'FHRSID': 1408425,
#  'LocalAuthorityBusinessID': 'PI/000078298',
#  'LocalAuthorityCode': '103',
#  'LocalAuthorityEmailAddress': 'fhrs@hastings.gov.uk',
#  'LocalAuthorityName': 'Hastings',
#  'LocalAuthorityWebSite': 'http://www.hastings.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN34 1RL',
#  'RatingDate': '2021-11-12T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf726b43'),
#  'geocode': {'latitude': 50.859935, 'longitude': 0.58419},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1408425',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 10}}
# {'AddressLine1': '1B Middle Row',
#  'AddressLine2': 'High Street',
#  'AddressLine3': 'Ashford',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Thai',
#  'BusinessType': 'Distributors/Transporters',
#  'BusinessTypeID': 7,
#  'ChangesByServerID': 0,
#  'Distance': 4605.975408818192,
#  'FHRSID': 1413549,
#  'LocalAuthorityBusinessID': 'PI/000100186',
#  'LocalAuthorityCode': '179',
#  'LocalAuthorityEmailAddress': 'envhealth@ashford.gov.uk',
#  'LocalAuthorityName': 'Ashford',
#  'LocalAuthorityWebSite': 'http://www.ashford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN24 8SQ',
#  'RatingDate': '2021-12-16T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf726be3'),
#  'geocode': {'latitude': 51.149166, 'longitude': 0.8729782},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1413549',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 10}}
# {'AddressLine1': '192 Speldhurst Close',
#  'AddressLine2': 'Stanhope',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Stanhope Mini Market',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4606.0675255400165,
#  'FHRSID': 264600,
#  'LocalAuthorityBusinessID': 'PI/000032871',
#  'LocalAuthorityCode': '179',
#  'LocalAuthorityEmailAddress': 'envhealth@ashford.gov.uk',
#  'LocalAuthorityName': 'Ashford',
#  'LocalAuthorityWebSite': 'http://www.ashford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN23 5TS',
#  'RatingDate': '2021-06-03T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf726c4f'),
#  'geocode': {'latitude': 51.128848, 'longitude': 0.849718},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/264600',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 10, 'Structural': 15}}
# {'AddressLine1': '155-157 Godinton Road',
#  'AddressLine2': 'Ashford',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': "Min's Convenience Store",
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4606.28165055893,
#  'FHRSID': 264653,
#  'LocalAuthorityBusinessID': 'PI/000010209',
#  'LocalAuthorityCode': '179',
#  'LocalAuthorityEmailAddress': 'envhealth@ashford.gov.uk',
#  'LocalAuthorityName': 'Ashford',
#  'LocalAuthorityWebSite': 'http://www.ashford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN23 1LN',
#  'RatingDate': '2022-07-08T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf726cb9'),
#  'geocode': {'latitude': 51.149312, 'longitude': 0.864736},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/264653',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 10}}
# {'AddressLine1': '74 Front Road',
#  'AddressLine2': 'Woodchurch',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Townland Stores',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4607.005356672748,
#  'FHRSID': 264713,
#  'LocalAuthorityBusinessID': 'PI/000031954',
#  'LocalAuthorityCode': '179',
#  'LocalAuthorityEmailAddress': 'envhealth@ashford.gov.uk',
#  'LocalAuthorityName': 'Ashford',
#  'LocalAuthorityWebSite': 'http://www.ashford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN26 3SA',
#  'RatingDate': '2022-07-13T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf726e06'),
#  'geocode': {'latitude': 51.077344, 'longitude': 0.771662},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/264713',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': 'Shop',
#  'AddressLine2': 'Ravenside',
#  'AddressLine3': 'Bexhill',
#  'AddressLine4': 'East Sussex',
#  'BusinessName': 'Truly Scrumptious',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4608.390289671764,
#  'FHRSID': 1030479,
#  'LocalAuthorityBusinessID': 'PI/000167084',
#  'LocalAuthorityCode': '106',
#  'LocalAuthorityEmailAddress': 'envhealth@rother.gov.uk',
#  'LocalAuthorityName': 'Rother',
#  'LocalAuthorityWebSite': 'http://www.rother.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN40 2JY',
#  'RatingDate': '2022-07-20T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf726fc0'),
#  'geocode': {'latitude': 50.8457221984863, 'longitude': 0.500949025154114},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1030479',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 15}}
# {'AddressLine1': '25 London Road',
#  'AddressLine2': 'Bexhill',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'Peters Fish Bar',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4609.377753189513,
#  'FHRSID': 761425,
#  'LocalAuthorityBusinessID': 'PI/000110523',
#  'LocalAuthorityCode': '106',
#  'LocalAuthorityEmailAddress': 'envhealth@rother.gov.uk',
#  'LocalAuthorityName': 'Rother',
#  'LocalAuthorityWebSite': 'http://www.rother.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN39 3JR',
#  'RatingDate': '2022-08-17T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf7270d1'),
#  'geocode': {'latitude': 50.841452, 'longitude': 0.469952},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/761425',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 15}}
# {'AddressLine1': 'Cafe',
#  'AddressLine2': '1-3 Windsor Road',
#  'AddressLine3': 'Bexhill',
#  'AddressLine4': 'East Sussex',
#  'BusinessName': 'Cafe Windsor',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4609.4197309271685,
#  'FHRSID': 761437,
#  'LocalAuthorityBusinessID': 'PI/000142097',
#  'LocalAuthorityCode': '106',
#  'LocalAuthorityEmailAddress': 'envhealth@rother.gov.uk',
#  'LocalAuthorityName': 'Rother',
#  'LocalAuthorityWebSite': 'http://www.rother.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN39 3PB',
#  'RatingDate': '2022-05-13T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf7270d7'),
#  'geocode': {'latitude': 50.841317, 'longitude': 0.468681},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/761437',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 15}}
# {'AddressLine1': '67 Seaside',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'Pistols',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4613.276158490939,
#  'FHRSID': 1197773,
#  'LocalAuthorityBusinessID': '81547',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN22 7NE',
#  'RatingDate': '2019-09-10T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf72742c'),
#  'geocode': {'latitude': 50.771543, 'longitude': 0.2952673},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1197773',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 15}}
# {'AddressLine1': '30 Seaside Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'Premier Halal Butcher',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4613.334699207242,
#  'FHRSID': 1282968,
#  'LocalAuthorityBusinessID': '81721',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 3PB',
#  'RatingDate': '2022-06-29T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf72749b'),
#  'geocode': {'latitude': 50.7681642, 'longitude': 0.2903527},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1282968',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 10, 'Structural': 5}}
# {'AddressLine1': 'Compton Street',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'Hudsons Fine Food',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4613.343803007081,
#  'FHRSID': 52101,
#  'LocalAuthorityBusinessID': '11729',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 4EJ',
#  'RatingDate': '2022-07-20T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf7274a7'),
#  'geocode': {'latitude': 50.760564, 'longitude': 0.282608},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/52101',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 5}}
# {'AddressLine1': '66-68 Leysdown Road',
#  'AddressLine2': 'Leysdown',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Pizza And Kebab',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4613.544190517785,
#  'FHRSID': 1388658,
#  'LocalAuthorityBusinessID': '21/500477/MIXED',
#  'LocalAuthorityCode': '189',
#  'LocalAuthorityEmailAddress': 'EHAdmin@MidKent.gov.uk',
#  'LocalAuthorityName': 'Swale',
#  'LocalAuthorityWebSite': 'http://www.swale.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12 4RE',
#  'RatingDate': '2021-12-14T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf727563'),
#  'geocode': {'latitude': 51.397645, 'longitude': 0.920001},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1388658',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 15}}
# {'AddressLine1': 'Priory Lane',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'Langney Sports Club Kitchen',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4613.601939936061,
#  'FHRSID': 144076,
#  'LocalAuthorityBusinessID': '821',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN23 7QH',
#  'RatingDate': '2022-05-27T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf7275a2'),
#  'geocode': {'latitude': 50.804421, 'longitude': 0.318965},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/144076',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 10}}
# {'AddressLine1': 'Priory Lane',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'Langney Sports Club Bar',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4613.601939936061,
#  'FHRSID': 736078,
#  'LocalAuthorityBusinessID': '79123',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN23 7QH',
#  'RatingDate': '2022-05-27T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf7275a3'),
#  'geocode': {'latitude': 50.804421, 'longitude': 0.318965},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/736078',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 10}}
# {'AddressLine1': '2 Station Parade',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'Station Convenience Store',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4613.78853202382,
#  'FHRSID': 143678,
#  'LocalAuthorityBusinessID': '81252',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BE',
#  'RatingDate': '2022-03-31T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf727628'),
#  'geocode': {'latitude': 50.769618, 'longitude': 0.279545},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/143678',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '89 Leysdown Road',
#  'AddressLine2': 'Leysdown',
#  'AddressLine3': 'Sheerness',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Little Groves Leisure Park',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4613.794785085501,
#  'FHRSID': 898129,
#  'LocalAuthorityBusinessID': 'PI/000101294/SW',
#  'LocalAuthorityCode': '189',
#  'LocalAuthorityEmailAddress': 'EHAdmin@MidKent.gov.uk',
#  'LocalAuthorityName': 'Swale',
#  'LocalAuthorityWebSite': 'http://www.swale.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12 4LL',
#  'RatingDate': '2021-10-29T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf72762f'),
#  'geocode': {'latitude': 51.399755, 'longitude': 0.9152645},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/898129',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 10, 'Structural': 10}}
# {'AddressLine1': '20 London Road',
#  'AddressLine2': 'Teynham',
#  'AddressLine3': 'Sittingbourne',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Dover Castle',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4615.114084928217,
#  'FHRSID': 1005172,
#  'LocalAuthorityBusinessID': '17/500551/MIXED',
#  'LocalAuthorityCode': '189',
#  'LocalAuthorityEmailAddress': 'EHAdmin@MidKent.gov.uk',
#  'LocalAuthorityName': 'Swale',
#  'LocalAuthorityWebSite': 'http://www.swale.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME9 9QS',
#  'RatingDate': '2022-07-20T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf727792'),
#  'geocode': {'latitude': 51.3267860412598, 'longitude': 0.803851008415222},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1005172',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 15}}
# {'AddressLine1': 'The Street',
#  'AddressLine2': 'Sissinghurst',
#  'AddressLine3': 'Cranbrook',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Sissinghurst Tandoori',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4615.869372591655,
#  'FHRSID': 67577,
#  'LocalAuthorityBusinessID': '15090/2049/2/000',
#  'LocalAuthorityCode': '192',
#  'LocalAuthorityEmailAddress': 'EHAdmin@Midkent.gov.uk',
#  'LocalAuthorityName': 'Tunbridge Wells',
#  'LocalAuthorityWebSite': 'http://www.tunbridgewells.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN17 2JJ',
#  'RatingDate': '2021-10-06T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf727822'),
#  'geocode': {'latitude': 51.108676, 'longitude': 0.56134},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/67577',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 5, 'Structural': 10}}
# {'AddressLine1': 'Retail Unit',
#  'AddressLine2': '11 Station Road',
#  'AddressLine3': 'Hurst Green',
#  'AddressLine4': 'East Sussex',
#  'BusinessName': 'Hurst Green Local',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4615.941095653411,
#  'FHRSID': 836361,
#  'LocalAuthorityBusinessID': 'PI/000159787',
#  'LocalAuthorityCode': '106',
#  'LocalAuthorityEmailAddress': 'envhealth@rother.gov.uk',
#  'LocalAuthorityName': 'Rother',
#  'LocalAuthorityWebSite': 'http://www.rother.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'TN19 7PL',
#  'RatingDate': '2022-03-30T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf727836'),
#  'geocode': {'latitude': 51.017786, 'longitude': 0.468006},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/836361',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 5, 'Structural': 10}}
# {'AddressLine1': 'Village Green Lane',
#  'AddressLine2': 'East Dean',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'Hikers Rest Coffee Shop',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4616.128551586063,
#  'FHRSID': 812885,
#  'LocalAuthorityBusinessID': 'PI/400005584',
#  'LocalAuthorityCode': '107',
#  'LocalAuthorityEmailAddress': 'envhealth@rother.gov.uk',
#  'LocalAuthorityName': 'Wealden',
#  'LocalAuthorityWebSite': 'http://www.wealden.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN20 0DR',
#  'RatingDate': '2022-03-15T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf72784b'),
#  'geocode': {'latitude': 50.758601, 'longitude': 0.205603},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/812885',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '21 East Street',
#  'AddressLine2': 'Sittingbourne',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Food And Wine',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4617.837208635523,
#  'FHRSID': 1382934,
#  'LocalAuthorityBusinessID': '21/500415/MIXED',
#  'LocalAuthorityCode': '189',
#  'LocalAuthorityEmailAddress': 'EHAdmin@MidKent.gov.uk',
#  'LocalAuthorityName': 'Swale',
#  'LocalAuthorityWebSite': 'http://www.swale.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME10 4BG',
#  'RatingDate': '2021-09-17T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf727970'),
#  'geocode': {'latitude': 51.339169, 'longitude': 0.741641},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1382934',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 0, 'Structural': 15}}
# {'AddressLine1': '91 High Street',
#  'AddressLine2': 'Walton On The Naze',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'Tollgate Fishery',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4617.90605645446,
#  'FHRSID': 658950,
#  'LocalAuthorityBusinessID': '12/00002/FOOD',
#  'LocalAuthorityCode': '120',
#  'LocalAuthorityEmailAddress': 'fhsadmin@tendringdc.gov.uk',
#  'LocalAuthorityName': 'Tendring',
#  'LocalAuthorityWebSite': 'http://www.tendringdc.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CO14 8AA',
#  'RatingDate': '2022-01-27T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf7279ab'),
#  'geocode': {'latitude': 51.849358, 'longitude': 1.271707},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/658950',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 10, 'Structural': 15}}
# {'AddressLine1': 'Ferry Boat Inn',
#  'AddressLine2': 'The Ferry',
#  'AddressLine3': 'Felixstowe',
#  'AddressLine4': 'Suffolk',
#  'BusinessName': 'The Ferryboat Felixstowe Ltd',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4618.9441394579,
#  'FHRSID': 659656,
#  'LocalAuthorityBusinessID': '06/64726/CP',
#  'LocalAuthorityCode': '302',
#  'LocalAuthorityEmailAddress': 'environment@eastsuffolk.gov.uk',
#  'LocalAuthorityName': 'East Suffolk',
#  'LocalAuthorityWebSite': 'http://www.eastsuffolk.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'IP11 9RZ',
#  'RatingDate': '2022-08-02T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf727b85'),
#  'geocode': {'latitude': 51.987107, 'longitude': 1.389532},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/659656',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 15}}
# {'AddressLine1': 'Unit 4',
#  'AddressLine2': 'Quartz Way',
#  'AddressLine3': 'Sittingbourne',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Kwuns Chinese Takeaway',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4619.1496672009325,
#  'FHRSID': 713966,
#  'LocalAuthorityBusinessID': 'PI/000080235/SW',
#  'LocalAuthorityCode': '189',
#  'LocalAuthorityEmailAddress': 'EHAdmin@MidKent.gov.uk',
#  'LocalAuthorityName': 'Swale',
#  'LocalAuthorityWebSite': 'http://www.swale.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'ME10 5AB',
#  'RatingDate': '2021-08-16T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926494f0d5feaf727bbf'),
#  'geocode': {'latitude': 51.350243, 'longitude': 0.716881},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/713966',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 5, 'Structural': 20}}
# {'AddressLine1': 'Anglia House',
# ...
#  'LocalAuthorityName': 'East Hertfordshire',
#  'LocalAuthorityWebSite': 'http://www.eastherts.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM21 9AR',
#  'RatingDate': '2022-08-03T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926694f0d5feaf72ef19'),
#  'geocode': {'latitude': 51.812753, 'longitude': 0.149267},
#  'latitude': None,
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/960098',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 15}}
# {'AddressLine1': '8 Terminus Street',
#  'AddressLine2': 'Harlow',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'Chicken Hut Harlow',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4657.269286879844,
#  'FHRSID': 1513021,
#  'LocalAuthorityBusinessID': 'COMM/22/00060',
#  'LocalAuthorityCode': '116',
#  'LocalAuthorityEmailAddress': 'env.health@harlow.gov.uk',
#  'LocalAuthorityName': 'Harlow',
#  'LocalAuthorityWebSite': 'http://www.harlow.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM20 1ES',
#  'RatingDate': '2022-07-05T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926694f0d5feaf72efdc'),
#  'geocode': {'latitude': 51.770653, 'longitude': 0.094796},
#  'latitude': None,
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1513021',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 15}}
# {'AddressLine1': '6-7 The Rows',
#  'AddressLine2': 'Harlow',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'International Shop',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4657.360635577399,
#  'FHRSID': 872672,
#  'LocalAuthorityBusinessID': 'COMM/13/20867',
#  'LocalAuthorityCode': '116',
#  'LocalAuthorityEmailAddress': 'env.health@harlow.gov.uk',
#  'LocalAuthorityName': 'Harlow',
#  'LocalAuthorityWebSite': 'http://www.harlow.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM20 1BZ',
#  'RatingDate': '2022-03-21T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926694f0d5feaf72f01c'),
#  'geocode': {'latitude': 51.7711442, 'longitude': 0.0927714},
#  'latitude': None,
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/872672',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 15}}
# {'AddressLine1': '4 Thorley Centre',
#  'AddressLine2': 'Villiers Sur Marne Avenue',
#  'AddressLine3': 'Bishops Stortford',
#  'AddressLine4': 'Hertfordshire',
#  'BusinessName': 'Flames Grill',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4658.712193410482,
#  'FHRSID': 715514,
#  'LocalAuthorityBusinessID': 'PI/000099534',
#  'LocalAuthorityCode': '157',
#  'LocalAuthorityEmailAddress': 'environmental.health@eastherts.gov.uk',
#  'LocalAuthorityName': 'East Hertfordshire',
#  'LocalAuthorityWebSite': 'http://www.eastherts.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM23 4EG',
#  'RatingDate': '2022-03-09T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926694f0d5feaf72f1ca'),
#  'geocode': {'latitude': 51.858647, 'longitude': 0.144482},
#  'latitude': None,
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/715514',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 10, 'Structural': 10}}
# {'AddressLine1': 'Thorley Centre',
#  'AddressLine2': 'Villiers Sur Marne Avenue',
#  'AddressLine3': 'Bishops Stortford',
#  'AddressLine4': 'Hertfordshire',
#  'BusinessName': 'Jades',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4658.712230258516,
#  'FHRSID': 337387,
#  'LocalAuthorityBusinessID': 'PI/000024173',
#  'LocalAuthorityCode': '157',
#  'LocalAuthorityEmailAddress': 'environmental.health@eastherts.gov.uk',
#  'LocalAuthorityName': 'East Hertfordshire',
#  'LocalAuthorityWebSite': 'http://www.eastherts.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM23 4EG',
#  'RatingDate': '2022-01-13T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926694f0d5feaf72f1ce'),
#  'geocode': {'latitude': 51.858648, 'longitude': 0.144482},
#  'latitude': None,
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/337387',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 15}}
# {'AddressLine1': '30 High Street',
#  'AddressLine2': 'Bishops Stortford',
#  'AddressLine3': 'Hertfordshire',
#  'AddressLine4': '',
#  'BusinessName': "Boar's Head Steak House And Grill",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4658.721502615029,
#  'FHRSID': 1502699,
#  'LocalAuthorityBusinessID': '22/00061/CP',
#  'LocalAuthorityCode': '157',
#  'LocalAuthorityEmailAddress': 'environmental.health@eastherts.gov.uk',
#  'LocalAuthorityName': 'East Hertfordshire',
#  'LocalAuthorityWebSite': 'http://www.eastherts.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM23 2LX',
#  'RatingDate': '2022-06-29T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '&lt;p&gt;\r\n'
#                  '\tFollowing the routine inspection we have improved hygiene '
#                  'standards.&lt;/p&gt;\r\n'
#                  '&lt;p&gt;\r\n'
#                  '\t&amp;nbsp;&lt;/p&gt;\r\n'
#                  '&lt;p&gt;\r\n'
#                  '\tNote from Environmental Health: Officers visited on the '
#                  '26th July 2022 and noted new procedures had been put in '
#                  'place following our intervention.&amp;nbsp; We will continue '
#                  'to monitor the implementation of these new procedures in '
#                  'line with the Food Law Code of Practice&lt;/p&gt;\r\n',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926694f0d5feaf72f1dd'),
#  'geocode': {'latitude': 51.871116, 'longitude': 0.156958},
#  'latitude': None,
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1502699',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 5}}
# {'AddressLine1': 'Dobbs Weir Cafe',
#  'AddressLine2': 'Dobbs Weir Road',
#  'AddressLine3': 'Roydon',
#  'AddressLine4': 'Harlow',
#  'BusinessName': 'River Palace Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4659.862511230976,
#  'FHRSID': 553818,
#  'LocalAuthorityBusinessID': 'PI/000200073',
#  'LocalAuthorityCode': '115',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@eppingforestdc.gov.uk',
#  'LocalAuthorityName': 'Epping Forest',
#  'LocalAuthorityWebSite': 'http://www.eppingforestdc.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'EN11 0AZ',
#  'RatingDate': '2022-07-26T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926694f0d5feaf72f247'),
#  'geocode': {'latitude': 51.754526, 'longitude': 0.006853},
#  'latitude': None,
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/553818',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 10, 'Structural': 10}}
# {'AddressLine1': '73 High Street',
#  'AddressLine2': 'Stanstead Abbotts',
#  'AddressLine3': 'Ware',
#  'AddressLine4': 'Hertfordshire',
#  'BusinessName': 'Khunnai Thai Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4661.157602932502,
#  'FHRSID': 744443,
#  'LocalAuthorityBusinessID': 'PI/000099678',
#  'LocalAuthorityCode': '157',
#  'LocalAuthorityEmailAddress': 'environmental.health@eastherts.gov.uk',
#  'LocalAuthorityName': 'East Hertfordshire',
#  'LocalAuthorityWebSite': 'http://www.eastherts.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SG12 8AS',
#  'RatingDate': '2022-06-08T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926694f0d5feaf72f2ce'),
#  'geocode': {'latitude': 51.788451, 'longitude': 0.005459},
#  'latitude': None,
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/744443',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 10, 'Structural': 15}}
# {'AddressLine1': '3 Market Row',
#  'AddressLine2': 'Saffron Walden',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'Saffron And Sage',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4661.326856134406,
#  'FHRSID': 1349142,
#  'LocalAuthorityBusinessID': '21/00028/COM',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'CB10 1HA',
#  'RatingDate': '2021-07-09T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926694f0d5feaf72f303'),
#  'geocode': {'latitude': 52.0231982, 'longitude': 0.2406154},
#  'latitude': None,
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1349142',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 15}}
# {'AddressLine1': '41 - 45 High Street',
#  'AddressLine2': 'Saffron Walden',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'Costcutters',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4661.3787907728165,
#  'FHRSID': 107635,
#  'LocalAuthorityBusinessID': '38090041000',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CB10 1AR',
#  'RatingDate': '2022-08-02T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926694f0d5feaf72f31d'),
#  'geocode': {'latitude': 52.022774, 'longitude': 0.238732},
#  'latitude': None,
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/107635',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 5, 'Structural': 10}}
# {'AddressLine1': '21 High Street',
#  'AddressLine2': 'Saffron Walden',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'BusinessName': 'The Mogul Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4661.433035114735,
#  'FHRSID': 107633,
#  'LocalAuthorityBusinessID': '3809002100X',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CB10 1AT',
#  'RatingDate': '2022-06-30T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926694f0d5feaf72f324'),
#  'geocode': {'latitude': 52.02372, 'longitude': 0.238196},
#  'latitude': None,
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/107633',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 15, 'Structural': 10}}
# {'AddressLine1': 'Barkway Golf Club Nuthampstead Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Barkway',
#  'AddressLine4': 'Hertfordshire',
#  'BusinessName': 'Barkway Park Golf Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4667.734641079181,
#  'FHRSID': 961242,
#  'LocalAuthorityBusinessID': '709149',
#  'LocalAuthorityCode': '159',
#  'LocalAuthorityEmailAddress': 'env.health@north-herts.gov.uk',
#  'LocalAuthorityName': 'North Hertfordshire',
#  'LocalAuthorityWebSite': 'http://www.north-herts.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SG8 8EN',
#  'RatingDate': '2022-02-23T00:00:00',
#  'RatingKey': 'fhrs_1_en-gb',
#  'RatingValue': 1,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66a2926694f0d5feaf72f38d'),
#  'geocode': {'latitude': 51.992134, 'longitude': 0.030555},
#  'latitude': None,
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/961242',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 10, 'Structural': 15}}
